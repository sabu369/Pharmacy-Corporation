# %% [markdown]
# #Pharmacy Coporation
#
# This code simulates a pharmacy organization, where multiple pharmacies manage their inventory, serve patients, and track sales. It generates weekly sales data for the entire year, storing this data in CSV files for each week. The code also compiles all the weekly data into a single DataFrame for comprehensive analysis.

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import random
from datetime import datetime
from datetime import timedelta
import altair as alt

# %% [markdown]
# # Class: Purchase
# This class is used to keep track of the total purchase amount for a given pharmacy. It has methods to increment the total by a given price and to return the total as a string.

# %%
#Define a class for purchase of a drug
class Purchase:
  #Initialize a sale with total amount
  def __init__(self):
    self.total = 0

  #Increment the total amount by a given price
  def increment(self, price):
    self.total += price
    self.total = round(self.total, 2)

  #Return the total amount of the sale
  def __str__(self):
      return "Sale: $" + str(self.total)

drugs = ['Ibuprofen', 'Tylenol', 'Naproxen', 'Excedrin', 'Aspirin', 'Sumatriptan', 'Rizatriptan']
quantities = ['10', '30', '60', '100']

# %% [markdown]
# # Class: Inventory
# This class represents the inventory of a pharmacy. It initializes with a random number of medication bottles, each with a random drug, quantity, and price. It provides a method to display the inventory.

# %%
#Define the Pharmacy Inventory class
class Inventory:
  def __init__(self):
      self.bottles = []

      num_bottles = random.randint(10, 20) #Generate a random number of products between 10 and 20

      for i in range(num_bottles):
          drug = random.choice(drugs) #Pick a drug
          quantity = random.choice(quantities) #Pick a size
          #price = round(random.uniform(5, 100), 2)#Random price between $5 and $100 within 2 digits
          bottle = Medication(drug, quantity)#Make a bottle with your values
          self.bottles.append(bottle) #Add the bottle to your inventory

  #Display all bottles in the inventory
  def display_order(self):
    result = ""
    for bottle in self.bottles:
      result += str(bottle) + "\n"
    return result

# %% [markdown]
# #  Class: Medication
# This class represents a medication with attributes for the drug name, quantity, and price. It provides a method to return these attributes as a string.

# %%
#My corporation is big pharmaceutical company and my stores are medical offices.
#Each medical office need order different medication and different quantity
#Define a class for medication
class Medication:
  #Initial the class with two attributes: drug, and quantity
    def __init__(self, drug, quantity):
      self.price = round(random.uniform(1,10), 2) #New price
      self.drug = random.choice(drugs)
      self.quantity = random.choice(quantities)

    #Return the drug, and quantity of the medication
    def __str__(self):
        return f'Drug: {self.drug}, Quantity: {self.quantity}'

# %% [markdown]
# #  Class: Pharmacy
# This class represents a pharmacy. It initializes with a name, an inventory, a list of patients, and a purchase object. It provides methods to add patients, run the simulation (where patients shop and purchase medications),and reset the total sales.

# %%
#Define a class for the pharmacy
class Pharmacy:
  #Initialize a pharmacy with a name, an inventory, a list of patients and a purchase object
  def __init__(self, name):
    self.name= name
    self.inventory = Inventory ()
    self.patients = []

    #New: buy things and add their number
    self.purchase = Purchase()

  #Add a patinet to the pharmacy
  def add_patient(self, patient):
      self.patients.append(patient)

  #Get the list of patients
  def getPatients(self):
      for patient in self.patients:
        print("Patient " + patient.getName() + " is currently shopping")

  #Run the simulation for the pharmacy
  def run(self):
      print("Welcome to " + self.name + "!")
      print("This is our inventory: " + "\n" + self.inventory.display_order())
      print("We have " + str(len(self.patients)) + " patients today.")

      for patient in self.patients: #Iterate over the patients
        print("Patient " + patient.name + " is shopping.")
        #Take one item from the inventory and add it to the patient's basket
        item = random.choice(self.inventory.bottles)
        patient.add_to_order(item)
        print("Patient " + patient.name + " added " + str(item) + " to their order.")

        #New: Create the ability to purchase things, and add that to a total
        self.purchase.increment(item.price) #Increment the sale object with the price of the item
        print("Patient " + patient.name + " checked out and paid $" + str(item.price) + ".")

      print("The total sales for " + self.name + " today is $" + str(self.purchase.total) + "." + "\n")

  #Return the name and the sale object of the pharmacy
  def __str__(self):
      return self.name + " (Sales: $" + str(self.purchase.total) + ")"

  #Reset the total sales for a pharmacy
  def reset_total_sales(self):
    self.purchase.total = 0

# %% [markdown]
# #  Class: Patient
# This class represents a patient. It initializes with a name and an order.  It provides methods to add a medication to the patient's order and to return the patient's information as a string.

# %%
#define class for patient
class Patient:

  #Initialize a patient with a name and an order
  def __init__(self, name):
    self.name = name
    self.order = Order ()

  #Get the name of the patient
  def getName(self):
        return self.name

  #Add a drug to the patient's order
  def add_to_order(self, drug):
      self.order.add(drug)

  #Return the name and the order of the patient
  def __str__(self):
      return self.name + " (" + str(self.order) + ")"

names = ["Kasey", "Cory", "William", "Jeff", "Lisa", "Hana", "Amy", "Beth", "Tyler", "Miki"]

# %% [markdown]
# #  Class: Order
# This class represents an order made by a patient. It initializes with an empty list of drugs. It provides methods to add a drug to the order and to return the list of drugs in the order as a string.

# %%
#Define a class for an order
class Order: #Slight variation on the store idea, where you might do a "order"

    #Initialize an order with a list of drugs
    def __init__(self):
      self.drugs = []

    #Add a drug to the order
    def add(self, drug):
      self.drugs.append(drug)

    #Return the list of drugs in the order
    def __str__(self):
      result = "Order:\n"
      for drug in self.drugs:
          result += str(drug) + "\n"
      return result

# %% [markdown]
# #  Class: Analytics
# This class is used to store and manage analytics data for the pharmacies. It provides methods to add analytics data and to create a CSV file from the analytics data.

# %%
#Define a class for analytics
class Analytics:
  def __init__(self):
    self.pharmacy_analytics = []

  #Add analytics data
  def add_analytics(self, analytics):
    self.pharmacy_analytics = analytics

  #Create a CSV file from the analytics data
  def make_csv(self):
    df = pd.DataFrame(self.pharmacy_analytics)
    print(df)
    entitle = week_date #title for the file we will build from it
    df.to_csv(entitle + ".csv", index=False)

# %% [markdown]
# #  Class: Organization
# This class represents the organization that owns multiple pharmacies. It initializes with a name and an empty list of pharmacies. It provides methods to add pharmacies, simulate the sales process for all pharmacies, display analytics data, and reset all pharmacy sales.

# %%
#Define a class for an organization
class Organization:

  #Initialize an organization with a name and a list of pharmacies
  def __init__(self, name):
    self.name = name
    self.pharmacies = []
    self.analytics = [] #new

  #Add a pharmacy to the organization
  def add_pharmacy(self, pharmacy):
      self.pharmacies.append(pharmacy)

  #Run the simulation for the organization
  def simulate (self):
      total_sales = 0
      print("Welcome to " + self.name + "!")
      print("We have " + str(len(self.pharmacies)) + " pharmacies in our corporation." + "\n")
      #Iterate over the pharmacies
      for pharmacy in self.pharmacies: #Iterate over the pharmacies

        pharmacy.run() #Run the simulaton for each pharmacy
        total_sales += pharmacy.purchase.total #Add each phamacy's total sales to the organization total

        #Add analytics data
        dict_A = {"Name":pharmacy.name, "total_sales":pharmacy.purchase.total}
        self.analytics.append(dict_A)

      print("The total sales for " + self.name + " today is $" + str(total_sales) + ".")

  #Get the analytics data
  def get_analytics(self):
      return self.analytics

  #Display the analytics data
  def display_analytics(self):
      for i in self.analytics:
        print(i )

  #Return the name and the list of pharmacies in the organization
  def __str__(self):
      result = self.name + ":\n"
      for pharmacy in self.pharmacies:
          result += str(pharmacy) + "\n"
      return result

  #Reset sales of all pharmacies in the organization
  def reset_all_pharmacy_sales(self):
    for pharmacy in self.pharmacies:
        pharmacy.reset_total_sales()

# %% [markdown]
# #  Simulation
# The following section sets up the organization and pharmacies, adds patients to each pharmacy, and runs a simulation to generate weekly sales data for each week of the year 2024. The data is stored in weekly CSV files and then compiled into a single DataFrame for analysis.

# %%
#Create a organization object
corp = Organization("Sabu Pharmaceutical Organization")

#Create some pharmacy objects
pharmacy1 = Pharmacy("Capitol Hill Pharmacy")
pharmacy2 = Pharmacy("Caton Hill Pharmacy")
pharmacy3 = Pharmacy("Largo Pharmacy")

#Add patients to each pharmacy
for name in names:
    pharmacy1.add_patient(Patient(name))
    pharmacy2.add_patient(Patient(name))
    pharmacy3.add_patient(Patient(name))


#Add phamarcies to the organization
corp.add_pharmacy(pharmacy1)
corp.add_pharmacy(pharmacy2)
corp.add_pharmacy(pharmacy3)

#Create an analytics object
analytic = Analytics()

# Generate weekly sales data for each week in 2024
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 12, 31)
current_date = start_date

while current_date <= end_date:
  weekly_totals_per_store = [] #Moved it inside the loop, to do once per file
  week_date = current_date.strftime('%B-%d-%Y')
  current_date += timedelta(days=7)  #Move to the next week

  corp.simulate()
  corp.display_analytics()
  analytic.add_analytics(corp.get_analytics())
  analytic.make_csv()
  corp.analytics.clear() #Clear out analytics each week
  corp.reset_all_pharmacy_sales()  #Reset total sales for each pharmacy

# %%
# Out:
# Streaming output truncated to the last 5000 lines.
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Aspirin, Quantity: 10 to their order.
# Patient Kasey checked out and paid $4.37.
# Patient Cory is shopping.
# Patient Cory added Drug: Aspirin, Quantity: 60 to their order.
# Patient Cory checked out and paid $8.63.
# Patient William is shopping.
# Patient William added Drug: Naproxen, Quantity: 10 to their order.
# Patient William checked out and paid $7.33.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Jeff checked out and paid $1.85.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Naproxen, Quantity: 100 to their order.
# Patient Lisa checked out and paid $3.03.
# Patient Hana is shopping.
# Patient Hana added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Hana checked out and paid $8.37.
# Patient Amy is shopping.
# Patient Amy added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Amy checked out and paid $3.46.
# Patient Beth is shopping.
# Patient Beth added Drug: Aspirin, Quantity: 30 to their order.
# Patient Beth checked out and paid $4.43.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Tylenol, Quantity: 30 to their order.
# Patient Tyler checked out and paid $8.54.
# Patient Miki is shopping.
# Patient Miki added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Miki checked out and paid $9.12.
# The total sales for Caton Hill Pharmacy today is $59.13.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Ibuprofen, Quantity: 60 to their order.
# Patient Kasey checked out and paid $6.11.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Cory checked out and paid $5.08.
# Patient William is shopping.
# Patient William added Drug: Ibuprofen, Quantity: 30 to their order.
# Patient William checked out and paid $3.1.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Naproxen, Quantity: 10 to their order.
# Patient Jeff checked out and paid $4.2.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient Lisa checked out and paid $5.91.
# Patient Hana is shopping.
# Patient Hana added Drug: Excedrin, Quantity: 30 to their order.
# Patient Hana checked out and paid $8.97.
# Patient Amy is shopping.
# Patient Amy added Drug: Naproxen, Quantity: 10 to their order.
# Patient Amy checked out and paid $7.58.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Beth checked out and paid $2.83.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Ibuprofen, Quantity: 60 to their order.
# Patient Tyler checked out and paid $6.11.
# Patient Miki is shopping.
# Patient Miki added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Miki checked out and paid $6.86.
# The total sales for Largo Pharmacy today is $56.75.
#
# The total sales for Sabu Pharmaceutical Organization today is $177.11.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 61.23}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 59.13}
# {'Name': 'Largo Pharmacy', 'total_sales': 56.75}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        61.23
# 1    Caton Hill Pharmacy        59.13
# 2         Largo Pharmacy        56.75
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Kasey checked out and paid $7.17.
# Patient Cory is shopping.
# Patient Cory added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Cory checked out and paid $7.48.
# Patient William is shopping.
# Patient William added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient William checked out and paid $6.69.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Excedrin, Quantity: 60 to their order.
# Patient Jeff checked out and paid $1.13.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 60 to their order.
# Patient Lisa checked out and paid $8.84.
# Patient Hana is shopping.
# Patient Hana added Drug: Tylenol, Quantity: 10 to their order.
# Patient Hana checked out and paid $2.23.
# Patient Amy is shopping.
# Patient Amy added Drug: Excedrin, Quantity: 60 to their order.
# Patient Amy checked out and paid $6.49.
# Patient Beth is shopping.
# Patient Beth added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Beth checked out and paid $7.17.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Excedrin, Quantity: 100 to their order.
# Patient Tyler checked out and paid $6.79.
# Patient Miki is shopping.
# Patient Miki added Drug: Excedrin, Quantity: 60 to their order.
# Patient Miki checked out and paid $6.49.
# The total sales for Capitol Hill Pharmacy today is $60.48.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Kasey checked out and paid $5.93.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Cory checked out and paid $5.01.
# Patient William is shopping.
# Patient William added Drug: Aspirin, Quantity: 100 to their order.
# Patient William checked out and paid $1.99.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Jeff checked out and paid $4.76.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Lisa checked out and paid $5.93.
# Patient Hana is shopping.
# Patient Hana added Drug: Aspirin, Quantity: 30 to their order.
# Patient Hana checked out and paid $4.43.
# Patient Amy is shopping.
# Patient Amy added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Amy checked out and paid $9.12.
# Patient Beth is shopping.
# Patient Beth added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Beth checked out and paid $9.12.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Tylenol, Quantity: 30 to their order.
# Patient Tyler checked out and paid $8.54.
# Patient Miki is shopping.
# Patient Miki added Drug: Tylenol, Quantity: 30 to their order.
# Patient Miki checked out and paid $8.54.
# The total sales for Caton Hill Pharmacy today is $63.37.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Naproxen, Quantity: 60 to their order.
# Patient Kasey checked out and paid $2.5.
# Patient Cory is shopping.
# Patient Cory added Drug: Naproxen, Quantity: 10 to their order.
# Patient Cory checked out and paid $7.58.
# Patient William is shopping.
# Patient William added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient William checked out and paid $5.91.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Naproxen, Quantity: 10 to their order.
# Patient Jeff checked out and paid $4.56.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Naproxen, Quantity: 10 to their order.
# Patient Lisa checked out and paid $4.2.
# Patient Hana is shopping.
# Patient Hana added Drug: Naproxen, Quantity: 10 to their order.
# Patient Hana checked out and paid $4.2.
# Patient Amy is shopping.
# Patient Amy added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Amy checked out and paid $5.08.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Beth checked out and paid $6.71.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Naproxen, Quantity: 10 to their order.
# Patient Tyler checked out and paid $4.56.
# Patient Miki is shopping.
# Patient Miki added Drug: Naproxen, Quantity: 10 to their order.
# Patient Miki checked out and paid $4.56.
# The total sales for Largo Pharmacy today is $49.86.
#
# The total sales for Sabu Pharmaceutical Organization today is $173.70999999999998.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 60.48}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 63.37}
# {'Name': 'Largo Pharmacy', 'total_sales': 49.86}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        60.48
# 1    Caton Hill Pharmacy        63.37
# 2         Largo Pharmacy        49.86
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Excedrin, Quantity: 100 to their order.
# Patient Kasey checked out and paid $6.79.
# Patient Cory is shopping.
# Patient Cory added Drug: Tylenol, Quantity: 10 to their order.
# Patient Cory checked out and paid $2.23.
# Patient William is shopping.
# Patient William added Drug: Excedrin, Quantity: 100 to their order.
# Patient William checked out and paid $6.79.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Excedrin, Quantity: 60 to their order.
# Patient Jeff checked out and paid $6.49.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 100 to their order.
# Patient Lisa checked out and paid $6.79.
# Patient Hana is shopping.
# Patient Hana added Drug: Excedrin, Quantity: 60 to their order.
# Patient Hana checked out and paid $8.84.
# Patient Amy is shopping.
# Patient Amy added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Amy checked out and paid $9.35.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Beth checked out and paid $9.35.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Excedrin, Quantity: 100 to their order.
# Patient Tyler checked out and paid $6.79.
# Patient Miki is shopping.
# Patient Miki added Drug: Tylenol, Quantity: 100 to their order.
# Patient Miki checked out and paid $7.5.
# The total sales for Capitol Hill Pharmacy today is $70.92.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Aspirin, Quantity: 10 to their order.
# Patient Kasey checked out and paid $3.91.
# Patient Cory is shopping.
# Patient Cory added Drug: Naproxen, Quantity: 10 to their order.
# Patient Cory checked out and paid $7.33.
# Patient William is shopping.
# Patient William added Drug: Naproxen, Quantity: 10 to their order.
# Patient William checked out and paid $7.33.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Naproxen, Quantity: 100 to their order.
# Patient Jeff checked out and paid $3.03.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Aspirin, Quantity: 30 to their order.
# Patient Lisa checked out and paid $4.43.
# Patient Hana is shopping.
# Patient Hana added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Hana checked out and paid $9.12.
# Patient Amy is shopping.
# Patient Amy added Drug: Aspirin, Quantity: 100 to their order.
# Patient Amy checked out and paid $2.06.
# Patient Beth is shopping.
# Patient Beth added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Beth checked out and paid $1.85.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Tyler checked out and paid $1.39.
# Patient Miki is shopping.
# Patient Miki added Drug: Aspirin, Quantity: 60 to their order.
# Patient Miki checked out and paid $8.63.
# The total sales for Caton Hill Pharmacy today is $49.08.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Kasey checked out and paid $6.71.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 10 to their order.
# Patient Cory checked out and paid $9.59.
# Patient William is shopping.
# Patient William added Drug: Naproxen, Quantity: 10 to their order.
# Patient William checked out and paid $4.2.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Naproxen, Quantity: 10 to their order.
# Patient Jeff checked out and paid $4.2.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 30 to their order.
# Patient Lisa checked out and paid $8.97.
# Patient Hana is shopping.
# Patient Hana added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Hana checked out and paid $6.71.
# Patient Amy is shopping.
# Patient Amy added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Amy checked out and paid $6.86.
# Patient Beth is shopping.
# Patient Beth added Drug: Naproxen, Quantity: 60 to their order.
# Patient Beth checked out and paid $2.5.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Tyler checked out and paid $6.71.
# Patient Miki is shopping.
# Patient Miki added Drug: Aspirin, Quantity: 60 to their order.
# Patient Miki checked out and paid $1.22.
# The total sales for Largo Pharmacy today is $57.67.
#
# The total sales for Sabu Pharmaceutical Organization today is $177.67000000000002.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 70.92}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 49.08}
# {'Name': 'Largo Pharmacy', 'total_sales': 57.67}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        70.92
# 1    Caton Hill Pharmacy        49.08
# 2         Largo Pharmacy        57.67
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Excedrin, Quantity: 60 to their order.
# Patient Kasey checked out and paid $6.49.
# Patient Cory is shopping.
# Patient Cory added Drug: Excedrin, Quantity: 60 to their order.
# Patient Cory checked out and paid $6.49.
# Patient William is shopping.
# Patient William added Drug: Excedrin, Quantity: 60 to their order.
# Patient William checked out and paid $1.13.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Excedrin, Quantity: 60 to their order.
# Patient Jeff checked out and paid $6.49.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 100 to their order.
# Patient Lisa checked out and paid $6.79.
# Patient Hana is shopping.
# Patient Hana added Drug: Excedrin, Quantity: 100 to their order.
# Patient Hana checked out and paid $6.79.
# Patient Amy is shopping.
# Patient Amy added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Amy checked out and paid $6.69.
# Patient Beth is shopping.
# Patient Beth added Drug: Excedrin, Quantity: 60 to their order.
# Patient Beth checked out and paid $8.84.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Tyler checked out and paid $9.35.
# Patient Miki is shopping.
# Patient Miki added Drug: Excedrin, Quantity: 60 to their order.
# Patient Miki checked out and paid $1.13.
# The total sales for Capitol Hill Pharmacy today is $60.19.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Aspirin, Quantity: 60 to their order.
# Patient Kasey checked out and paid $8.63.
# Patient Cory is shopping.
# Patient Cory added Drug: Tylenol, Quantity: 30 to their order.
# Patient Cory checked out and paid $8.54.
# Patient William is shopping.
# Patient William added Drug: Aspirin, Quantity: 100 to their order.
# Patient William checked out and paid $7.57.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Aspirin, Quantity: 30 to their order.
# Patient Jeff checked out and paid $4.43.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Aspirin, Quantity: 100 to their order.
# Patient Lisa checked out and paid $7.57.
# Patient Hana is shopping.
# Patient Hana added Drug: Aspirin, Quantity: 10 to their order.
# Patient Hana checked out and paid $3.91.
# Patient Amy is shopping.
# Patient Amy added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Amy checked out and paid $4.76.
# Patient Beth is shopping.
# Patient Beth added Drug: Aspirin, Quantity: 10 to their order.
# Patient Beth checked out and paid $4.37.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Aspirin, Quantity: 10 to their order.
# Patient Tyler checked out and paid $3.91.
# Patient Miki is shopping.
# Patient Miki added Drug: Naproxen, Quantity: 10 to their order.
# Patient Miki checked out and paid $7.33.
# The total sales for Caton Hill Pharmacy today is $61.02.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Sumatriptan, Quantity: 10 to their order.
# Patient Kasey checked out and paid $9.59.
# Patient Cory is shopping.
# Patient Cory added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient Cory checked out and paid $5.91.
# Patient William is shopping.
# Patient William added Drug: Naproxen, Quantity: 60 to their order.
# Patient William checked out and paid $8.13.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Jeff checked out and paid $7.15.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Lisa checked out and paid $6.71.
# Patient Hana is shopping.
# Patient Hana added Drug: Excedrin, Quantity: 30 to their order.
# Patient Hana checked out and paid $8.97.
# Patient Amy is shopping.
# Patient Amy added Drug: Naproxen, Quantity: 60 to their order.
# Patient Amy checked out and paid $8.13.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Beth checked out and paid $2.83.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Tyler checked out and paid $5.08.
# Patient Miki is shopping.
# Patient Miki added Drug: Naproxen, Quantity: 60 to their order.
# Patient Miki checked out and paid $2.5.
# The total sales for Largo Pharmacy today is $65.0.
#
# The total sales for Sabu Pharmaceutical Organization today is $186.21.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 60.19}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 61.02}
# {'Name': 'Largo Pharmacy', 'total_sales': 65.0}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        60.19
# 1    Caton Hill Pharmacy        61.02
# 2         Largo Pharmacy        65.00
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Kasey checked out and paid $9.35.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Cory checked out and paid $6.33.
# Patient William is shopping.
# Patient William added Drug: Tylenol, Quantity: 10 to their order.
# Patient William checked out and paid $2.23.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Naproxen, Quantity: 60 to their order.
# Patient Jeff checked out and paid $1.56.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 60 to their order.
# Patient Lisa checked out and paid $1.13.
# Patient Hana is shopping.
# Patient Hana added Drug: Tylenol, Quantity: 10 to their order.
# Patient Hana checked out and paid $2.23.
# Patient Amy is shopping.
# Patient Amy added Drug: Tylenol, Quantity: 100 to their order.
# Patient Amy checked out and paid $7.5.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Beth checked out and paid $7.48.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Excedrin, Quantity: 60 to their order.
# Patient Tyler checked out and paid $6.49.
# Patient Miki is shopping.
# Patient Miki added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Miki checked out and paid $7.48.
# The total sales for Capitol Hill Pharmacy today is $51.78.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Aspirin, Quantity: 100 to their order.
# Patient Kasey checked out and paid $2.06.
# Patient Cory is shopping.
# Patient Cory added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Cory checked out and paid $8.37.
# Patient William is shopping.
# Patient William added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient William checked out and paid $9.12.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Tylenol, Quantity: 100 to their order.
# Patient Jeff checked out and paid $4.76.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Lisa checked out and paid $5.01.
# Patient Hana is shopping.
# Patient Hana added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Hana checked out and paid $9.12.
# Patient Amy is shopping.
# Patient Amy added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Amy checked out and paid $4.76.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Beth checked out and paid $8.18.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Naproxen, Quantity: 10 to their order.
# Patient Tyler checked out and paid $7.33.
# Patient Miki is shopping.
# Patient Miki added Drug: Aspirin, Quantity: 60 to their order.
# Patient Miki checked out and paid $8.63.
# The total sales for Caton Hill Pharmacy today is $67.34.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Kasey checked out and paid $2.83.
# Patient Cory is shopping.
# Patient Cory added Drug: Naproxen, Quantity: 10 to their order.
# Patient Cory checked out and paid $4.56.
# Patient William is shopping.
# Patient William added Drug: Sumatriptan, Quantity: 10 to their order.
# Patient William checked out and paid $9.59.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient Jeff checked out and paid $5.91.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Lisa checked out and paid $2.83.
# Patient Hana is shopping.
# Patient Hana added Drug: Ibuprofen, Quantity: 30 to their order.
# Patient Hana checked out and paid $3.1.
# Patient Amy is shopping.
# Patient Amy added Drug: Excedrin, Quantity: 30 to their order.
# Patient Amy checked out and paid $8.97.
# Patient Beth is shopping.
# Patient Beth added Drug: Ibuprofen, Quantity: 30 to their order.
# Patient Beth checked out and paid $3.1.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Naproxen, Quantity: 10 to their order.
# Patient Tyler checked out and paid $7.58.
# Patient Miki is shopping.
# Patient Miki added Drug: Sumatriptan, Quantity: 10 to their order.
# Patient Miki checked out and paid $9.59.
# The total sales for Largo Pharmacy today is $58.06.
#
# The total sales for Sabu Pharmaceutical Organization today is $177.18.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 51.78}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 67.34}
# {'Name': 'Largo Pharmacy', 'total_sales': 58.06}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        51.78
# 1    Caton Hill Pharmacy        67.34
# 2         Largo Pharmacy        58.06
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Excedrin, Quantity: 60 to their order.
# Patient Kasey checked out and paid $8.84.
# Patient Cory is shopping.
# Patient Cory added Drug: Excedrin, Quantity: 100 to their order.
# Patient Cory checked out and paid $6.79.
# Patient William is shopping.
# Patient William added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient William checked out and paid $6.69.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Excedrin, Quantity: 60 to their order.
# Patient Jeff checked out and paid $1.13.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 60 to their order.
# Patient Lisa checked out and paid $8.84.
# Patient Hana is shopping.
# Patient Hana added Drug: Tylenol, Quantity: 100 to their order.
# Patient Hana checked out and paid $7.5.
# Patient Amy is shopping.
# Patient Amy added Drug: Tylenol, Quantity: 10 to their order.
# Patient Amy checked out and paid $2.23.
# Patient Beth is shopping.
# Patient Beth added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Beth checked out and paid $6.33.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Excedrin, Quantity: 60 to their order.
# Patient Tyler checked out and paid $1.13.
# Patient Miki is shopping.
# Patient Miki added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Miki checked out and paid $6.33.
# The total sales for Capitol Hill Pharmacy today is $55.81.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Kasey checked out and paid $4.76.
# Patient Cory is shopping.
# Patient Cory added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Cory checked out and paid $1.85.
# Patient William is shopping.
# Patient William added Drug: Tylenol, Quantity: 30 to their order.
# Patient William checked out and paid $8.54.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Aspirin, Quantity: 30 to their order.
# Patient Jeff checked out and paid $4.43.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Lisa checked out and paid $3.46.
# Patient Hana is shopping.
# Patient Hana added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Hana checked out and paid $3.46.
# Patient Amy is shopping.
# Patient Amy added Drug: Aspirin, Quantity: 60 to their order.
# Patient Amy checked out and paid $8.63.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Beth checked out and paid $8.18.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Tyler checked out and paid $8.37.
# Patient Miki is shopping.
# Patient Miki added Drug: Aspirin, Quantity: 60 to their order.
# Patient Miki checked out and paid $8.63.
# The total sales for Caton Hill Pharmacy today is $60.31.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Naproxen, Quantity: 10 to their order.
# Patient Kasey checked out and paid $4.56.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Cory checked out and paid $5.08.
# Patient William is shopping.
# Patient William added Drug: Naproxen, Quantity: 10 to their order.
# Patient William checked out and paid $7.58.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Sumatriptan, Quantity: 10 to their order.
# Patient Jeff checked out and paid $9.59.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Lisa checked out and paid $6.86.
# Patient Hana is shopping.
# Patient Hana added Drug: Aspirin, Quantity: 60 to their order.
# Patient Hana checked out and paid $1.22.
# Patient Amy is shopping.
# Patient Amy added Drug: Ibuprofen, Quantity: 30 to their order.
# Patient Amy checked out and paid $3.1.
# Patient Beth is shopping.
# Patient Beth added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Beth checked out and paid $6.86.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient Tyler checked out and paid $5.91.
# Patient Miki is shopping.
# Patient Miki added Drug: Naproxen, Quantity: 10 to their order.
# Patient Miki checked out and paid $4.56.
# The total sales for Largo Pharmacy today is $55.32.
#
# The total sales for Sabu Pharmaceutical Organization today is $171.44.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 55.81}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 60.31}
# {'Name': 'Largo Pharmacy', 'total_sales': 55.32}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        55.81
# 1    Caton Hill Pharmacy        60.31
# 2         Largo Pharmacy        55.32
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Kasey checked out and paid $7.48.
# Patient Cory is shopping.
# Patient Cory added Drug: Excedrin, Quantity: 60 to their order.
# Patient Cory checked out and paid $6.49.
# Patient William is shopping.
# Patient William added Drug: Tylenol, Quantity: 10 to their order.
# Patient William checked out and paid $2.23.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Jeff checked out and paid $6.33.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 100 to their order.
# Patient Lisa checked out and paid $6.79.
# Patient Hana is shopping.
# Patient Hana added Drug: Excedrin, Quantity: 60 to their order.
# Patient Hana checked out and paid $1.13.
# Patient Amy is shopping.
# Patient Amy added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Amy checked out and paid $9.35.
# Patient Beth is shopping.
# Patient Beth added Drug: Excedrin, Quantity: 100 to their order.
# Patient Beth checked out and paid $6.79.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Tyler checked out and paid $6.33.
# Patient Miki is shopping.
# Patient Miki added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Miki checked out and paid $7.48.
# The total sales for Capitol Hill Pharmacy today is $60.4.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Aspirin, Quantity: 100 to their order.
# Patient Kasey checked out and paid $7.57.
# Patient Cory is shopping.
# Patient Cory added Drug: Aspirin, Quantity: 10 to their order.
# Patient Cory checked out and paid $4.37.
# Patient William is shopping.
# Patient William added Drug: Aspirin, Quantity: 60 to their order.
# Patient William checked out and paid $8.63.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Naproxen, Quantity: 100 to their order.
# Patient Jeff checked out and paid $3.03.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Tylenol, Quantity: 100 to their order.
# Patient Lisa checked out and paid $4.76.
# Patient Hana is shopping.
# Patient Hana added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Hana checked out and paid $8.18.
# Patient Amy is shopping.
# Patient Amy added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Amy checked out and paid $1.39.
# Patient Beth is shopping.
# Patient Beth added Drug: Aspirin, Quantity: 10 to their order.
# Patient Beth checked out and paid $4.37.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Aspirin, Quantity: 100 to their order.
# Patient Tyler checked out and paid $1.99.
# Patient Miki is shopping.
# Patient Miki added Drug: Aspirin, Quantity: 30 to their order.
# Patient Miki checked out and paid $4.43.
# The total sales for Caton Hill Pharmacy today is $48.72.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Kasey checked out and paid $2.83.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Cory checked out and paid $7.15.
# Patient William is shopping.
# Patient William added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient William checked out and paid $7.15.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Tylenol, Quantity: 30 to their order.
# Patient Jeff checked out and paid $2.21.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Naproxen, Quantity: 60 to their order.
# Patient Lisa checked out and paid $2.5.
# Patient Hana is shopping.
# Patient Hana added Drug: Naproxen, Quantity: 60 to their order.
# Patient Hana checked out and paid $8.13.
# Patient Amy is shopping.
# Patient Amy added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Amy checked out and paid $2.83.
# Patient Beth is shopping.
# Patient Beth added Drug: Naproxen, Quantity: 10 to their order.
# Patient Beth checked out and paid $4.56.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Naproxen, Quantity: 10 to their order.
# Patient Tyler checked out and paid $4.56.
# Patient Miki is shopping.
# Patient Miki added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Miki checked out and paid $2.83.
# The total sales for Largo Pharmacy today is $44.75.
#
# The total sales for Sabu Pharmaceutical Organization today is $153.87.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 60.4}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 48.72}
# {'Name': 'Largo Pharmacy', 'total_sales': 44.75}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        60.40
# 1    Caton Hill Pharmacy        48.72
# 2         Largo Pharmacy        44.75
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Excedrin, Quantity: 100 to their order.
# Patient Kasey checked out and paid $6.79.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Cory checked out and paid $6.33.
# Patient William is shopping.
# Patient William added Drug: Tylenol, Quantity: 10 to their order.
# Patient William checked out and paid $2.23.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Excedrin, Quantity: 60 to their order.
# Patient Jeff checked out and paid $8.84.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Excedrin, Quantity: 100 to their order.
# Patient Lisa checked out and paid $6.79.
# Patient Hana is shopping.
# Patient Hana added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Hana checked out and paid $7.17.
# Patient Amy is shopping.
# Patient Amy added Drug: Excedrin, Quantity: 100 to their order.
# Patient Amy checked out and paid $6.79.
# Patient Beth is shopping.
# Patient Beth added Drug: Naproxen, Quantity: 60 to their order.
# Patient Beth checked out and paid $1.56.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Naproxen, Quantity: 60 to their order.
# Patient Tyler checked out and paid $1.56.
# Patient Miki is shopping.
# Patient Miki added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Miki checked out and paid $9.35.
# The total sales for Capitol Hill Pharmacy today is $57.41.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Tylenol, Quantity: 100 to their order.
# Patient Kasey checked out and paid $4.76.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Cory checked out and paid $5.01.
# Patient William is shopping.
# Patient William added Drug: Aspirin, Quantity: 100 to their order.
# Patient William checked out and paid $7.57.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Aspirin, Quantity: 10 to their order.
# Patient Jeff checked out and paid $4.37.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Lisa checked out and paid $4.76.
# Patient Hana is shopping.
# Patient Hana added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Hana checked out and paid $9.12.
# Patient Amy is shopping.
# Patient Amy added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Amy checked out and paid $1.39.
# Patient Beth is shopping.
# Patient Beth added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Beth checked out and paid $8.18.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Tyler checked out and paid $5.93.
# Patient Miki is shopping.
# Patient Miki added Drug: Naproxen, Quantity: 100 to their order.
# Patient Miki checked out and paid $3.03.
# The total sales for Caton Hill Pharmacy today is $54.12.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Ibuprofen, Quantity: 60 to their order.
# Patient Kasey checked out and paid $6.11.
# Patient Cory is shopping.
# Patient Cory added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient Cory checked out and paid $5.91.
# Patient William is shopping.
# Patient William added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient William checked out and paid $6.86.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Naproxen, Quantity: 10 to their order.
# Patient Jeff checked out and paid $7.58.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Aspirin, Quantity: 60 to their order.
# Patient Lisa checked out and paid $1.22.
# Patient Hana is shopping.
# Patient Hana added Drug: Naproxen, Quantity: 60 to their order.
# Patient Hana checked out and paid $2.5.
# Patient Amy is shopping.
# Patient Amy added Drug: Naproxen, Quantity: 60 to their order.
# Patient Amy checked out and paid $2.5.
# Patient Beth is shopping.
# ...
# Patient Lisa checked out and paid $8.54.
# Patient Hana is shopping.
# Patient Hana added Drug: Aspirin, Quantity: 10 to their order.
# Patient Hana checked out and paid $4.37.
# Patient Amy is shopping.
# Patient Amy added Drug: Rizatriptan, Quantity: 100 to their order.
# Patient Amy checked out and paid $8.18.
# Patient Beth is shopping.
# Patient Beth added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Beth checked out and paid $1.85.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Aspirin, Quantity: 100 to their order.
# Patient Tyler checked out and paid $1.99.
# Patient Miki is shopping.
# Patient Miki added Drug: Aspirin, Quantity: 10 to their order.
# Patient Miki checked out and paid $3.91.
# The total sales for Caton Hill Pharmacy today is $49.73.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Kasey checked out and paid $6.86.
# Patient Cory is shopping.
# Patient Cory added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Cory checked out and paid $6.71.
# Patient William is shopping.
# Patient William added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient William checked out and paid $5.91.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Jeff checked out and paid $5.08.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Lisa checked out and paid $6.86.
# Patient Hana is shopping.
# Patient Hana added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Hana checked out and paid $2.83.
# Patient Amy is shopping.
# Patient Amy added Drug: Naproxen, Quantity: 10 to their order.
# Patient Amy checked out and paid $7.58.
# Patient Beth is shopping.
# Patient Beth added Drug: Naproxen, Quantity: 60 to their order.
# Patient Beth checked out and paid $2.5.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Tyler checked out and paid $2.83.
# Patient Miki is shopping.
# Patient Miki added Drug: Excedrin, Quantity: 30 to their order.
# Patient Miki checked out and paid $8.97.
# The total sales for Largo Pharmacy today is $56.13.
#
# The total sales for Sabu Pharmaceutical Organization today is $142.03.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 36.17}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 49.73}
# {'Name': 'Largo Pharmacy', 'total_sales': 56.13}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        36.17
# 1    Caton Hill Pharmacy        49.73
# 2         Largo Pharmacy        56.13
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Excedrin, Quantity: 100 to their order.
# Patient Kasey checked out and paid $6.79.
# Patient Cory is shopping.
# Patient Cory added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Cory checked out and paid $9.35.
# Patient William is shopping.
# Patient William added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient William checked out and paid $7.48.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Excedrin, Quantity: 60 to their order.
# Patient Jeff checked out and paid $8.84.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Lisa checked out and paid $6.33.
# Patient Hana is shopping.
# Patient Hana added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Hana checked out and paid $7.17.
# Patient Amy is shopping.
# Patient Amy added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Amy checked out and paid $6.33.
# Patient Beth is shopping.
# Patient Beth added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Beth checked out and paid $6.69.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Tyler checked out and paid $9.35.
# Patient Miki is shopping.
# Patient Miki added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Miki checked out and paid $7.48.
# The total sales for Capitol Hill Pharmacy today is $75.81.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Naproxen, Quantity: 10 to their order.
# Patient Kasey checked out and paid $7.33.
# Patient Cory is shopping.
# Patient Cory added Drug: Naproxen, Quantity: 100 to their order.
# Patient Cory checked out and paid $3.03.
# Patient William is shopping.
# Patient William added Drug: Aspirin, Quantity: 100 to their order.
# Patient William checked out and paid $1.99.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Aspirin, Quantity: 100 to their order.
# Patient Jeff checked out and paid $1.99.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Lisa checked out and paid $4.76.
# Patient Hana is shopping.
# Patient Hana added Drug: Aspirin, Quantity: 100 to their order.
# Patient Hana checked out and paid $7.57.
# Patient Amy is shopping.
# Patient Amy added Drug: Tylenol, Quantity: 30 to their order.
# Patient Amy checked out and paid $8.54.
# Patient Beth is shopping.
# Patient Beth added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Beth checked out and paid $5.93.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Tyler checked out and paid $1.85.
# Patient Miki is shopping.
# Patient Miki added Drug: Tylenol, Quantity: 100 to their order.
# Patient Miki checked out and paid $4.76.
# The total sales for Caton Hill Pharmacy today is $47.75.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Aspirin, Quantity: 60 to their order.
# Patient Kasey checked out and paid $1.22.
# Patient Cory is shopping.
# Patient Cory added Drug: Excedrin, Quantity: 30 to their order.
# Patient Cory checked out and paid $8.97.
# Patient William is shopping.
# Patient William added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient William checked out and paid $5.08.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Jeff checked out and paid $7.15.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 10 to their order.
# Patient Lisa checked out and paid $6.71.
# Patient Hana is shopping.
# Patient Hana added Drug: Ibuprofen, Quantity: 30 to their order.
# Patient Hana checked out and paid $3.1.
# Patient Amy is shopping.
# Patient Amy added Drug: Ibuprofen, Quantity: 30 to their order.
# Patient Amy checked out and paid $3.1.
# Patient Beth is shopping.
# Patient Beth added Drug: Ibuprofen, Quantity: 30 to their order.
# Patient Beth checked out and paid $3.1.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Ibuprofen, Quantity: 60 to their order.
# Patient Tyler checked out and paid $6.11.
# Patient Miki is shopping.
# Patient Miki added Drug: Tylenol, Quantity: 30 to their order.
# Patient Miki checked out and paid $2.21.
# The total sales for Largo Pharmacy today is $46.75.
#
# The total sales for Sabu Pharmaceutical Organization today is $170.31.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 75.81}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 47.75}
# {'Name': 'Largo Pharmacy', 'total_sales': 46.75}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        75.81
# 1    Caton Hill Pharmacy        47.75
# 2         Largo Pharmacy        46.75
# Welcome to Sabu Pharmaceutical Organization!
# We have 3 pharmacies in our corporation.
#
# Welcome to Capitol Hill Pharmacy!
# This is our inventory:
# Drug: Excedrin, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Excedrin, Quantity: 100
# Drug: Sumatriptan, Quantity: 100
# Drug: Rizatriptan, Quantity: 60
# Drug: Excedrin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Tylenol, Quantity: 100 to their order.
# Patient Kasey checked out and paid $7.5.
# Patient Cory is shopping.
# Patient Cory added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Cory checked out and paid $7.17.
# Patient William is shopping.
# Patient William added Drug: Naproxen, Quantity: 60 to their order.
# Patient William checked out and paid $1.56.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Jeff checked out and paid $6.33.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Naproxen, Quantity: 60 to their order.
# Patient Lisa checked out and paid $1.56.
# Patient Hana is shopping.
# Patient Hana added Drug: Excedrin, Quantity: 60 to their order.
# Patient Hana checked out and paid $8.84.
# Patient Amy is shopping.
# Patient Amy added Drug: Excedrin, Quantity: 60 to their order.
# Patient Amy checked out and paid $8.84.
# Patient Beth is shopping.
# Patient Beth added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Beth checked out and paid $6.69.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Tylenol, Quantity: 10 to their order.
# Patient Tyler checked out and paid $2.23.
# Patient Miki is shopping.
# Patient Miki added Drug: Sumatriptan, Quantity: 100 to their order.
# Patient Miki checked out and paid $6.69.
# The total sales for Capitol Hill Pharmacy today is $57.41.
#
# Welcome to Caton Hill Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 30
# Drug: Naproxen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Tylenol, Quantity: 30
# Drug: Rizatriptan, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Tylenol, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Ibuprofen, Quantity: 100
# Drug: Rizatriptan, Quantity: 100
# Drug: Aspirin, Quantity: 10
# Drug: Ibuprofen, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Aspirin, Quantity: 100
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Aspirin, Quantity: 100 to their order.
# Patient Kasey checked out and paid $2.06.
# Patient Cory is shopping.
# Patient Cory added Drug: Tylenol, Quantity: 30 to their order.
# Patient Cory checked out and paid $8.54.
# Patient William is shopping.
# Patient William added Drug: Aspirin, Quantity: 100 to their order.
# Patient William checked out and paid $7.57.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Tylenol, Quantity: 100 to their order.
# Patient Jeff checked out and paid $4.76.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Ibuprofen, Quantity: 100 to their order.
# Patient Lisa checked out and paid $1.39.
# Patient Hana is shopping.
# Patient Hana added Drug: Aspirin, Quantity: 100 to their order.
# Patient Hana checked out and paid $2.06.
# Patient Amy is shopping.
# Patient Amy added Drug: Aspirin, Quantity: 100 to their order.
# Patient Amy checked out and paid $2.06.
# Patient Beth is shopping.
# Patient Beth added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Beth checked out and paid $5.01.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Tyler checked out and paid $5.01.
# Patient Miki is shopping.
# Patient Miki added Drug: Rizatriptan, Quantity: 60 to their order.
# Patient Miki checked out and paid $4.76.
# The total sales for Caton Hill Pharmacy today is $43.22.
#
# Welcome to Largo Pharmacy!
# This is our inventory:
# Drug: Rizatriptan, Quantity: 30
# Drug: Rizatriptan, Quantity: 10
# Drug: Excedrin, Quantity: 30
# Drug: Sumatriptan, Quantity: 30
# Drug: Ibuprofen, Quantity: 30
# Drug: Sumatriptan, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Aspirin, Quantity: 60
# Drug: Sumatriptan, Quantity: 60
# Drug: Tylenol, Quantity: 30
# Drug: Naproxen, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 10
# Drug: Naproxen, Quantity: 10
# Drug: Sumatriptan, Quantity: 100
# Drug: Ibuprofen, Quantity: 60
# Drug: Naproxen, Quantity: 60
# Drug: Rizatriptan, Quantity: 10
#
# We have 10 patients today.
# Patient Kasey is shopping.
# Patient Kasey added Drug: Naproxen, Quantity: 10 to their order.
# Patient Kasey checked out and paid $7.58.
# Patient Cory is shopping.
# Patient Cory added Drug: Tylenol, Quantity: 30 to their order.
# Patient Cory checked out and paid $2.21.
# Patient William is shopping.
# Patient William added Drug: Sumatriptan, Quantity: 10 to their order.
# Patient William checked out and paid $9.59.
# Patient Jeff is shopping.
# Patient Jeff added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Jeff checked out and paid $7.15.
# Patient Lisa is shopping.
# Patient Lisa added Drug: Rizatriptan, Quantity: 30 to their order.
# Patient Lisa checked out and paid $5.91.
# Patient Hana is shopping.
# Patient Hana added Drug: Sumatriptan, Quantity: 60 to their order.
# Patient Hana checked out and paid $5.08.
# Patient Amy is shopping.
# Patient Amy added Drug: Naproxen, Quantity: 10 to their order.
# Patient Amy checked out and paid $4.56.
# Patient Beth is shopping.
# Patient Beth added Drug: Naproxen, Quantity: 60 to their order.
# Patient Beth checked out and paid $2.5.
# Patient Tyler is shopping.
# Patient Tyler added Drug: Naproxen, Quantity: 60 to their order.
# Patient Tyler checked out and paid $2.5.
# Patient Miki is shopping.
# Patient Miki added Drug: Naproxen, Quantity: 10 to their order.
# Patient Miki checked out and paid $7.58.
# The total sales for Largo Pharmacy today is $54.66.
#
# The total sales for Sabu Pharmaceutical Organization today is $155.29.
# {'Name': 'Capitol Hill Pharmacy', 'total_sales': 57.41}
# {'Name': 'Caton Hill Pharmacy', 'total_sales': 43.22}
# {'Name': 'Largo Pharmacy', 'total_sales': 54.66}
#                     Name  total_sales
# 0  Capitol Hill Pharmacy        57.41
# 1    Caton Hill Pharmacy        43.22
# 2         Largo Pharmacy        54.66

# %% [markdown]
# ### Summarize all CSV files into a Single DataFrame
# This section aggregates weekly sales data from multiple CSV files into a single DataFrame for comprehensive analysis.
#
# 1. **Import Libraries**: Import the `os` and `pandas` libraries.
# 2. **Get Current Directory**: Retrieve and print the current working directory.
# 3. **List CSV Files**: List and print all CSV files in the directory.
# 4. **Initialize Sales Data List**: Create an empty list to hold sales data from all CSV files.
# 5. **Read and Aggregate CSV Files**:
#    - Read each CSV file into a DataFrame.
#    - Extract the week name from the filename.
#    - Append each row's data to the master list, adding the week name.
# 6. **Create and Print DataFrame**: Convert the master list into a DataFrame and print it.

# %%
#Summarize all CSV files into a single DataFrame

import os

#Get the current directory (where the Colab notebook is running)
current_directory = os.getcwd()
print(current_directory)

#List all files in the current directory
all_files = os.listdir(current_directory)

#Filter only the CSV files
csv_files = [file for file in all_files if file.endswith('.csv')]

print(csv_files)

#Initialize the master list for all sales data
all_stores_all_weekly_sales = []  #Global list to hold data from all CSV files

#Read each CSV file, extract rows, and append to the master list
for filename in csv_files:
    df = pd.read_csv(filename)
    week_name = filename.replace('.csv', '')  #Extract week name from filename
    for _, row in df.iterrows():
        row_dict = row.to_dict()
        row_dict['week'] = week_name  #Add the week name to each row's data
        all_stores_all_weekly_sales.append(row_dict)

#Print the first few rows from the master list
print(all_stores_all_weekly_sales)

#Create a DataFrame from the list
df = pd.DataFrame(all_stores_all_weekly_sales)

#Print the DataFrame
print(df)
# Out:
# /content
# ['April-22-2024.csv', 'December-02-2024.csv', 'November-18-2024.csv', 'January-22-2024.csv', 'January-15-2024.csv', 'July-01-2024.csv', 'September-09-2024.csv', 'February-26-2024.csv', 'October-14-2024.csv', 'June-24-2024.csv', 'February-19-2024.csv', 'August-12-2024.csv', 'June-10-2024.csv', 'May-27-2024.csv', 'February-12-2024.csv', 'April-15-2024.csv', 'May-06-2024.csv', 'December-16-2024.csv', 'July-15-2024.csv', 'September-30-2024.csv', 'November-04-2024.csv', 'March-18-2024.csv', 'April-01-2024.csv', 'December-09-2024.csv', 'October-07-2024.csv', 'April-08-2024.csv', 'June-17-2024.csv', 'February-05-2024.csv', 'May-20-2024.csv', 'September-16-2024.csv', 'January-08-2024.csv', 'March-11-2024.csv', 'October-21-2024.csv', 'July-29-2024.csv', 'May-13-2024.csv', 'August-19-2024.csv', 'December-30-2024.csv', 'November-11-2024.csv', 'March-04-2024.csv', 'September-23-2024.csv', 'March-25-2024.csv', 'November-25-2024.csv', 'August-26-2024.csv', 'September-02-2024.csv', 'July-08-2024.csv', 'January-01-2024.csv', 'December-23-2024.csv', 'June-03-2024.csv', 'January-29-2024.csv', 'October-28-2024.csv', 'July-22-2024.csv', 'April-29-2024.csv', 'August-05-2024.csv']
# [{'Name': 'Capitol Hill Pharmacy', 'total_sales': 68.84, 'week': 'April-22-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 64.37, 'week': 'April-22-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 62.09, 'week': 'April-22-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 45.36, 'week': 'December-02-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 53.74, 'week': 'December-02-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 60.54, 'week': 'December-02-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 58.14, 'week': 'November-18-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 43.68, 'week': 'November-18-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 74.94, 'week': 'November-18-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 63.37, 'week': 'January-22-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 63.48, 'week': 'January-22-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 63.43, 'week': 'January-22-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 56.05, 'week': 'January-15-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 47.95, 'week': 'January-15-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 47.53, 'week': 'January-15-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 60.19, 'week': 'July-01-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 61.02, 'week': 'July-01-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 65.0, 'week': 'July-01-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 51.31, 'week': 'September-09-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 56.99, 'week': 'September-09-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 60.97, 'week': 'September-09-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 62.53, 'week': 'February-26-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 53.44, 'week': 'February-26-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 65.95, 'week': 'February-26-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 56.74, 'week': 'October-14-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 51.31, 'week': 'October-14-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 48.76, 'week': 'October-14-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 70.92, 'week': 'June-24-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 49.08, 'week': 'June-24-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 57.67, 'week': 'June-24-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 70.3, 'week': 'February-19-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 58.66, 'week': 'February-19-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 52.61, 'week': 'February-19-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 55.16, 'week': 'August-12-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 56.28, 'week': 'August-12-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 66.48, 'week': 'August-12-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 61.23, 'week': 'June-10-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 59.13, 'week': 'June-10-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 56.75, 'week': 'June-10-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 63.89, 'week': 'May-27-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 60.49, 'week': 'May-27-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 43.23, 'week': 'May-27-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 62.18, 'week': 'February-12-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 52.42, 'week': 'February-12-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 74.6, 'week': 'February-12-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 56.3, 'week': 'April-15-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 42.11, 'week': 'April-15-2024'}, {'Name': 'Largo Pharmacy', 'total_sales': 62.62, 'week': 'April-15-2024'}, {'Name': 'Capitol Hill Pharmacy', 'total_sales': 54.03, 'week': 'May-06-2024'}, {'Name': 'Caton Hill Pharmacy', 'total_sales': 58.71, 'week': 'May-0 ...
#                       Name  total_sales              week
# 0    Capitol Hill Pharmacy        68.84     April-22-2024
# 1      Caton Hill Pharmacy        64.37     April-22-2024
# 2           Largo Pharmacy        62.09     April-22-2024
# 3    Capitol Hill Pharmacy        45.36  December-02-2024
# 4      Caton Hill Pharmacy        53.74  December-02-2024
# ..                     ...          ...               ...
# 154    Caton Hill Pharmacy        38.32     April-29-2024
# 155         Largo Pharmacy        53.49     April-29-2024
# 156  Capitol Hill Pharmacy        74.65    August-05-2024
# 157    Caton Hill Pharmacy        62.79    August-05-2024
# 158         Largo Pharmacy        71.64    August-05-2024
#
# [159 rows x 3 columns]

# %% [markdown]
# ### Visualize Sales Data with Altair
# This section creates an interactive line chart using Altair to visualize weekly total sales data for each pharmacy.
#
# 1. **Set Chart Dimensions**: Define the chart's width and height.
# 2. **Create Base Line Chart**:
#    - Use `df` DataFrame for the chart data.
#    - Encode the x-axis with 'week' (temporal), y-axis with 'total_sales' (quantitative), and differentiate lines by 'Name' (nominal).
#    - Add tooltips to display 'Name', 'total_sales', and 'week' on hover.
# 3. **Enable Interaction**: Make the chart interactive.
# 4. **Display the Chart**: Render the chart.

# %%
#Assuming 'df' is your DataFrame with the 'Name', 'total_sales', and 'week' columns

#Define the width and height for the chart
width = 800  #Set the width to be twice of a typical value (e.g., 400)
height = 300  #Set the height

#Create a base line chart with specified width and height
base = alt.Chart(df, width=width, height=height).mark_line().encode(
    x='week:T',  #Encode the x-axis with the 'week' column as temporal data
    y='total_sales:Q',  #Encode the y-axis with the 'total_sales' column as quantitative data
    color='Name:N',  #Use the 'Name' column to differentiate lines by color (nominal data)
    tooltip=['Name:N', 'total_sales:Q', 'week:T']  #Add tooltips to show 'Name', 'total_sales', and 'week' on hover
).interactive()  #Enable interaction with the chart

# Display the chart
base
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Calculate Descriptive Statistics and Variance
# This section computes descriptive statistics and variance for total sales, grouped by each pharmacy.
#
# 1. **Group by Pharmacy Name**: Group the DataFrame by 'Name' and calculate descriptive statistics for 'total_sales'.
# 2. **Calculate Variance**: Compute the variance of 'total_sales' for each pharmacy and rename the resulting Series.
# 3. **Combine Statistics and Variance**: Merge the descriptive statistics and variance into a single DataFrame.
# 4. **Print the Combined DataFrame**: Display the DataFrame with statistics and variance for each pharmacy.

# %%
#Group the DataFrame by 'Name' and calculate descriptive statistics for 'total_sales'
grouped_stats = df.groupby('Name')['total_sales'].describe()

#Calculate the variance for 'total_sales' for each store and rename the resulting Series
grouped_variance = df.groupby('Name')['total_sales'].var().rename("variance")

#Combine the descriptive statistics and variance into single DataFrame
stats_with_variance = pd.concat([grouped_stats, grouped_variance], axis=1)

#Print the combined DataFrame containing statistics and variance for each store
print(stats_with_variance)
# Out:
#                        count       mean       std    min    25%    50%    75%  \
# Name
# Capitol Hill Pharmacy   53.0  60.726415  8.680039  36.17  55.81  59.01  65.51
# Caton Hill Pharmacy     53.0  52.785849  8.847905  31.82  46.12  52.83  59.13
# Largo Pharmacy          53.0  56.662830  8.885318  33.21  49.86  57.67  62.09
#
#                          max   variance
# Name
# Capitol Hill Pharmacy  80.82  75.343085
# Caton Hill Pharmacy    70.47  78.285421
# Largo Pharmacy         74.94  78.948875

# %% [markdown]
# ### Rank Stores by Variance in Total Sales
# This section ranks stores based on the variance in total sales, assuming 'df' is the DataFrame with 'name', 'total_sales', and 'week' columns.
#
# 1. **Calculate Variance and Rank**: Compute the variance of 'total_sales' for each store and rank the stores in descending order based on variance.
# 2. **Print the Ranked Stores**: Display the stores ranked by variance in total sales.

# %%
#Assuming 'df' is your DataFrame with the 'name', 'total_sales', and 'week' columns


#Rank the stores by their variance in 'total_sales' in descending order
ranked_stores = grouped_variance.sort_values(ascending=False)

# Print the ranked stores based on variance
print(ranked_stores)
# Out:
# Name
# Largo Pharmacy           78.948875
# Caton Hill Pharmacy      78.285421
# Capitol Hill Pharmacy    75.343085
# Name: variance, dtype: float64

# %% [markdown]
# ### Visualize Store Ranking with Variance Histogram
# This section creates a bar chart (histogram) to visualize the variance of total sales for each store, assuming 'ranked_stores' is a Pandas Series with store names as the index and variance as the values.
#
# 1. **Convert Series to DataFrame**: Convert the 'ranked_stores' Series to a DataFrame suitable for use with Altair.
# 2. **Define Color Scale**: Define the color scale with a midpoint for the variance values.
# 3. **Create Bar Chart**: Use Altair to create a bar chart (histogram) to display store ranking based on variance of total sales.
# 4. **Display the Histogram**: Render the histogram chart.

# %%
#Assuming 'ranked_stores' is a Pandas Series with the store names as the index and variance as the values

#Convert the 'ranked_stores' Series to a DataFrame for use with Altair
data = ranked_stores.reset_index()
data.columns = ['Name', 'variance']

#Define the color scale with a midpoint for the variance values
color_scale = alt.Scale(scheme='redblue', domainMid=0)

#Create a bar chart (histogram) to visualize the variance of total sales for each store
histogram = alt.Chart(data).mark_bar().encode(
    x='Name:N',  #Nominal data type for store names on the x-axis
    y='variance:Q',  #Quantitative data type for variance on the y-axis
    color=alt.Color('variance:Q', scale=color_scale, legend=None),  #Color bars based on variance
    tooltip=['Name:N', 'variance:Q']  #Tooltips to display store names and variance
).properties(
    width=800  #Set the width of the chart
)

# Display the histogram
histogram
# Out:
# alt.Chart(...)
